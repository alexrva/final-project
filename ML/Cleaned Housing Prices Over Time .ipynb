# %%
import pandas as pd

# %%
df1 = train = pd.read_csv("Cityhousingtime.csv")
df1
# Out:
#      RegionID                          RegionName  SizeRank   1996-04  \
# 0      102001                       United States         0  106409.0
# 1      394913                        New York, NY         1  189376.0
# 2      753899  Los Angeles-Long Beach-Anaheim, CA         2  192140.0
# 3      394463                         Chicago, IL         3  162321.0
# 4      394514               Dallas-Fort Worth, TX         4  113140.0
# ..        ...                                 ...       ...       ...
# 909    394767                          Lamesa, TX       909       NaN
# 910    753874                           Craig, CO       910   63465.0
# 911    394968                           Pecos, TX       911       NaN
# 912    395188                          Vernon, TX       912       NaN
# 913    394743                       Ketchikan, AK       913       NaN
#
#       1996-05   1996-06   1996-07   1996-08   1996-09   1996-10  ...  2019-05  \
# ...

# %%
new = df1[['RegionName', '1996-12', '1997-12', '1998-12', '1999-12', '2000-12', '2001-12', '2002-12', '2003-12', '2004-12', '2005-12', '2006-12', '2007-12','2008-12','2009-12','2010-12','2011-12', '2012-12', '2013-12','2014-12', '2015-12', '2016-12', '2017-12', '2018-12', '2019-12']]
new
# Out:
#                              RegionName   1996-12   1997-12   1998-12  \
# 0                         United States  108145.0  111739.0  117204.0
# 1                          New York, NY  188884.0  196018.0  205420.0
# 2    Los Angeles-Long Beach-Anaheim, CA  192403.0  198410.0  218319.0
# 3                           Chicago, IL  166231.0  150420.0  159830.0
# 4                 Dallas-Fort Worth, TX  115355.0  117739.0  120555.0
# ..                                  ...       ...       ...       ...
# 909                          Lamesa, TX       NaN       NaN       NaN
# 910                           Craig, CO   66522.0   70397.0   79331.0
# 911                           Pecos, TX       NaN       NaN       NaN
# 912                          Vernon, TX       NaN       NaN       NaN
# 913                       Ketchikan, AK       NaN       NaN       NaN
#
#       1999-12   2000-12   2001-12   2002-12   2003-12   2004-12  ...  \
# ...

# %%
new = new.rename(columns = {'1996-12':'1996', '1997-12':'1997','1998-12':'1998','1999-12':'1999','2000-12':'2000','2001-12':'2001','2002-12':'2002','2003-12':'2003','2004-12':'2004','2005-12':'2005','2006-12':'2006','2007-12':'2007','2008-12':'2008','2009-12':'2009','2010-12':'2010','2011-12':'2011','2012-12':'2012','2013-12':'2013','2014-12':'2014','2015-12':'2015','2016-12':'2016','2017-12':'2017','2018-12':'2018','2019-12':'2019' })
new
# Out:
#                              RegionName      1996      1997      1998  \
# 0                         United States  108145.0  111739.0  117204.0
# 1                          New York, NY  188884.0  196018.0  205420.0
# 2    Los Angeles-Long Beach-Anaheim, CA  192403.0  198410.0  218319.0
# 3                           Chicago, IL  166231.0  150420.0  159830.0
# 4                 Dallas-Fort Worth, TX  115355.0  117739.0  120555.0
# ..                                  ...       ...       ...       ...
# 909                          Lamesa, TX       NaN       NaN       NaN
# 910                           Craig, CO   66522.0   70397.0   79331.0
# 911                           Pecos, TX       NaN       NaN       NaN
# 912                          Vernon, TX       NaN       NaN       NaN
# 913                       Ketchikan, AK       NaN       NaN       NaN
#
#          1999      2000      2001      2002      2003      2004  ...  \
# ...

# %%
new.to_csv('cleanedHousing.csv')

# %%
new.set_index("RegionName", inplace=True)
new.head()
# Out:
#                                         1996      1997      1998      1999  \
# RegionName
# United States                       108145.0  111739.0  117204.0  124155.0
# New York, NY                        188884.0  196018.0  205420.0  225341.0
# Los Angeles-Long Beach-Anaheim, CA  192403.0  198410.0  218319.0  238822.0
# Chicago, IL                         166231.0  150420.0  159830.0  168823.0
# Dallas-Fort Worth, TX               115355.0  117739.0  120555.0  129551.0
#
#                                         2000      2001      2002      2003  \
# RegionName
# United States                       132951.0  141859.0  151623.0  163198.0
# New York, NY                        253470.0  283893.0  323439.0  366605.0
# Los Angeles-Long Beach-Anaheim, CA  264858.0  293163.0  345872.0  413296.0
# Chicago, IL                         183105.0  197767.0  212292.0  227584.0
# Dallas-Fort Worth, TX               133189.0  133986.0  139920.0  142115.0
#
# ...

# %%
newYork = new.loc['New York, NY']
newYork
# Out:
# 1996    188884.0
# 1997    196018.0
# 1998    205420.0
# 1999    225341.0
# 2000    253470.0
# 2001    283893.0
# 2002    323439.0
# 2003    366605.0
# 2004    417192.0
# 2005    471984.0
# 2006    484688.0
# 2007    468871.0
# 2008    433356.0
# 2009    404782.0
# 2010    398517.0
# 2011    379265.0
# 2012    373853.0
# 2013    391112.0
# 2014    403113.0
# 2015    413712.0
# 2016    427803.0
# 2017    451891.0
# 2018    473751.0
# 2019    478297.0
# Name: New York, NY, dtype: float64

# %%
newYork.to_csv('NewYorkHousing.csv')
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """Entry point for launching an IPython kernel.
