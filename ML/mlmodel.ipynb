# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import pylab
import sklearn
from sklearn.preprocessing import PolynomialFeatures
import pandas as pd

# %%
mldf = pd.read_csv("normalized/denver.csv")

# %%
mldf
# Out:
#        date  region_id      city statecode  unemployment  housing  deltaunemp  \
# 0  3/1/2003       6752  Richmond        VA           4.2   120901           0
#
#    deltastocks    threem  threed  time
# 0        -87.2  6/1/2003    3603     2

# %%
X = mldf[['deltastocks','deltaunemp']]
y = mldf["threed"].values.reshape(-1, 1)
print(X.shape, y.shape)
# Out:
# (198, 2) (198, 1)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# Fitting our model with all of our features in X
model.fit(X, y)

score = model.score(X, y)
print(f"R2 Score: {score}")
# Out:
# R2 Score: 0.03869740859134463

# %%
# model.predict(predict_)

# %%
print('Weight coefficients: ', model.coef_)
print('y-axis intercept: ', model.intercept_)
# Out:
# Weight coefficients:  [[    3.90532573 -1312.74890411]]
# y-axis intercept:  [3275.01758244]

# %%
predictions = model.predict(X)
print(f"True output: {y[0]}")
print(f"Predicted output: {predictions[0]}")
print(f"Prediction Error: {predictions[0]-y[0]}")
# Out:
# True output: [-1346]
# Predicted output: [-5691.95467804]
# Prediction Error: [-4345.95467804]

# %%
score = model.score(X, y)
print(f"R2 Score: {score}")
# Out:
# R2 Score: 0.03869740859134463

# %%
from sklearn.metrics import mean_squared_error, r2_score

predicted = model.predict(X)

mse = mean_squared_error(y, predicted)
r2 = r2_score(y, predicted)

print(f"Mean Squared Error (MSE): {mse}")
print(f"R-squared (R2 ): {r2}")
# Out:
# Mean Squared Error (MSE): 25755203.19356873
# R-squared (R2 ): 0.03869740859134463

# %%
plt.scatter(X, y)
i=10
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-290-f9bacfb8ec60> in <module>
# ----> 1 plt.scatter(X, y)
#       2 i=10
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2845         verts=verts, edgecolors=edgecolors,
#    2846         plotnonfinite=plotnonfinite, **({"data": data} if data is not
# -> 2847         None else {}), **kwargs)
#    2848     sci(__ret)
#    2849     return __ret
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
#    1603         bound = new_sig.bind(ax, *args, **kwargs)
#
# ...

# %%
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
mldf = pd.read_csv("normalized/denver.csv")

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

x =mldf['deltastocks']
y =mldf['deltaunemp']
z =mldf['threed']

ax.set_xlim3d(-583.7, 947.8)
ax.set_ylim3d(-0.2,4.2)
ax.set_zlim3d(min(z), max(z))

ax.scatter(x, y, z, c='r', marker='o')

ax.set_xlabel('Stock Delta Composit')
ax.set_ylabel('Unemployment Delta')
ax.set_zlabel('Housing Prediction Delta')


plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

x =mldf.head(i)['deltastocks']
y =mldf.head(i)['deltaunemp']
z =mldf.head(i)['threed']


ax.set_xlim3d(-583.7, 947.8)
ax.set_ylim3d(-0.2,4.2)
ax.set_zlim3d(-6616, 7109)

ax.scatter(x, y, z, c='r', marker='o')

ax.set_xlabel('Stock Delta Composit')
ax.set_ylabel('Unemployment Delta')
ax.set_zlabel('Housing Prediction Delta')

plt.savefig('d' + str(i) + '.png')


plt.show()
i = i+1
print(i)
# Out:
# 201

# %%
plt.savefig('richguess')

# %%
for i in range(len(mldf)):
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    time = mldf.iloc[i, 10]
    x = mldf.iloc[i, 7]
    y = mldf.iloc[i, 6]
    z = mldf.iloc[i, 9]
    ax.set_xlim3d(-583.7, 947.8)
    ax.set_ylim3d(-0.2,4.2)
    ax.set_zlim3d(-6616, 7109)
    ax.scatter(x, y, z, c='r', marker='o')
    ax.set_xlabel('Stock Delta Composit')
    ax.set_ylabel('Unemployment Delta')
    ax.set_zlabel('Housing Price')
    plt.show()
