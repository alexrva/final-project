# %%
import pandas as pd
df = pd.read_csv('CityDataFinal.csv')
df.head()
# Out:
#    ranking          city statecode  avg_sal     med_h  med_r  avg_h_temp  \
# 0        5    Des Moines        IA    50600  178942.0    857        60.3
# 1        4  Fayetteville        AR    45830  177942.0    778        68.0
# 2       12       Madison        WI    52190  247967.0    958        55.9
# 3       11    Huntsville        AL    53600  167300.0    779         NaN
# 4        2        Denver        CO    57400  393842.0   1203        64.6
#
#    avg_l_temp  med_age  unemp  ...  mbs  rent12  rent_by_sal  rbs  \
# 0        41.4     35.7    2.4  ...    9   10284          14%   14
# 1        45.0     33.9    2.7  ...   19    9336          17%   17
# 2        36.8     35.9    2.2  ...   13   11496          11%   11
# 3         NaN     38.4    3.5  ...   14    9348          16%   16
# 4        36.2     36.3    3.0  ...   29   14436          19%   19
#
#    rent_mtg_avg rma_weight our_rank  combined score  weighted score rank
# ...

# %%
# Alex, I got the code to work for the first 2 columns but it was giving me trouble with the mtg30.
# I tried to get a dataframe from what I had and that did not work.
# my forhead is red from banging it on my desk. It's all yours. HOT POTATO!

def avgint(column):
    x = df[[column]].mean()
    y = x.real.astype(int)[0]
    return y



avgsdata = {'avgSalary': avgint("avg_sal"),
            'avgHouse(total)': avgint("med_h"),
#             'avgHouse(monthly)': avgint("mtg30"),
#             'avgRent(monthly)': avgint("rent12")
           }


# avgdf = pd.DataFrame(data = avgsdata, columns = ['avgSalary','avgHouse(total)','avgHouse(monthly)','avgRent(monthly)'])
avgdf = pd.DataFrame(data = avgsdata, columns = ['avgSalary','avgHouse(total)'])
# Out:
# C:\Users\ryand\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: `real` is deprecated and will be removed in a future version. To eliminate this warning for a Series `ser`, use `np.real(ser.to_numpy())` or `ser.to_numpy().real`.
#   This is separate from the ipykernel package so we can avoid doing imports until
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-57a10cdf12e2> in <module>
#      14
#      15 # avgdf = pd.DataFrame(data = avgsdata, columns = ['avgSalary','avgHouse(total)','avgHouse(monthly)','avgRent(monthly)'])
# ---> 16 avgdf = pd.DataFrame(data = avgsdata, columns = ['avgSalary','avgHouse(total)'])
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     409             )
#     410         elif isinstance(data, dict):
# ...
