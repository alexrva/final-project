# %%
# Dependencies and Setup
import os
import pandas as pd

# %%
df = pd.read_csv("final_df_weights_added_columns.csv")
df.set_index('Ranking', inplace=True)
df.head()
# Out:
#                      City     State Average Salary Median Houseing Cost  \
# Ranking
# 1                  Austin     Texas        $51,840             $291,533
# 2                  Denver  Colorado        $57,400             $393,842
# 3        Colorado Springs  Colorado        $50,050             $286,700
# 4            Fayetteville  Arkansas        $45,830             $177,942
# 5              Des Moines      Iowa        $50,600             $178,942
#
#         Median Rent  Average High Temperature  Average Low Temperature  \
# Ranking
# 1            $1,155                      79.7                     54.8
# 2            $1,203                      64.6                     36.2
# 3            $1,070                      62.1                     35.7
# 4              $778                      68.0                     45.0
# 5              $857                      60.3                     41.4
#
#          Median Age  Unemployment Rate  Metro Population  \
# Ranking
# ...

# %%
df.to_html('CitySearchData.html')
